# %% [markdown]
# # TASK #1: PLOT INTERACTIVE SCATTERPLOT USING PLOTLY EXPRESS

# %%
import plotly.express as px
import pandas as pd

salary_df = px.df = pd.read_csv('/workspaces/Coding/Plotly/employee_salaries.csv')
display(salary_df)
# Plot Years of Experience Vs. Salary Using Plolty Express
chart = px.scatter(salary_df, x = 'Years_of_Experience', y = 'Salary', color_discrete_sequence = px.colors.qualitative.Alphabet)
chart.show()
# Out:
#       Years_of_Experience        Salary
# 0                1.000000   40000.00000
# 1                2.257942   65979.42119
# 2                2.450875   67253.57549
# 3                2.498713   67342.43510
# 4                2.613729   70532.20448
# ...                   ...           ...
# 1995            19.178575  421534.69100
# 1996            19.254499  430478.02650
# 1997            19.353369  438090.84540
# 1998            19.842520  482242.16080
# 1999            20.000000  500000.00000
#
# [2000 rows x 2 columns]
# ...

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Plot the scatter plot for GRE Score vs. chance of admission**
# - **What do you infer from that plot?**
# - **Use the color attribute to show the university rating as a third dimension**

# %%
# Let's import another more advanced dataset entitled University admission (university_admission)

# GRE Scores (out of 340)
# TOEFL Scores (out of 120)
# University Rating (out of 5)
# Statement of Purpose (SOP) 
# Letter of Recommendation (LOR) Strength (out of 5)
# Undergraduate GPA (out of 10)
# Research Experience (either 0 or 1)
# Chance of admission (ranging from 0 to 1)

# %%
admission_df = pd.read_csv('/workspaces/Coding/Plotly/university_admission.csv')
display(admission_df)

chart = px.scatter(admission_df, x = 'GRE Score', y = "Chance of Admit", color = 'University Rating', color_continuous_scale = px.colors.qualitative.Alphabet)
chart.show()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %% [markdown]
# # TASK #2: PLOT INTERACTIVE BUBBLE CHART (SCATTERPLOT WITH SIZE)

# %%
# Let's add a fourth variable "SOP" as the size 
chart = px.scatter(admission_df, x = "GRE Score", y = "Chance of Admit", color = "University Rating", size = "SOP")
chart.show()
# Out:
# <div>                            <div id="9687a1db-7fb7-4d49-bf0d-721149c36e6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9687a1db-7fb7-4d49-bf0d-721149c36e6f")) {                    Plotly.newPlot(                        "9687a1db-7fb7-4d49-bf0d-721149c36e6f",                        [{"hovertemplate":"GRE Score=%{x}\u003cbr\u003eChance of Admit=%{y}\u003cbr\u003eSOP=%{marker.size}\u003cbr\u003eUniversity Rating=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[4,4,3,3,2,5,3,2,1,3,3,4,4,3,3,3,3,3,3,3,3,4,5,5,5,5,5,2,1,2,2,3,4,5,5,5,2,1,1,2,3,2,2,4,5,5,5,5,3,4,3,2,4,4,3,3,3,2,1,2,2,3,2,2,3,4,3,2,3,4,5,5,5,4,3,2,3,2,2,1,3,4,5,5,5,4,3,2,3,4,2,3,2,2,3,4,2,3,4,3,3,2,2,2,3,3,4,4,5,5,5,4,3,2,3,4,3,4,2,5,5,5,
# ...

# %%
chart = px.scatter(admission_df, x = "GRE Score", y = "Chance of Admit", color = "University Rating", size = "SOP", hover_data = 'LOR')
chart.show()
# Out:
# <div>                            <div id="1fea35a4-452e-4b5d-b1db-288656596a2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fea35a4-452e-4b5d-b1db-288656596a2d")) {                    Plotly.newPlot(                        "1fea35a4-452e-4b5d-b1db-288656596a2d",                        [{"customdata":[[4.5],[4.5],[3.5],[2.5],[3.0],[3.0],[4.0],[4.0],[1.5],[3.0],[4.0],[4.5],[4.5],[3.0],[2.0],[2.5],[3.0],[3.0],[3.0],[3.0],[2.0],[2.0],[5.0],[4.5],[3.5],[4.5],[3.5],[2.5],[2.0],[2.0],[3.0],[4.0],[4.5],[4.0],[5.0],[5.0],[4.0],[2.0],[1.5],[3.5],[3.0],[2.5],[2.0],[4.0],[4.0],[4.0],[5.0],[4.0],[5.0],[4.0],[4.5],[3.5],[3.0],[2.5],[3.5],[3.0],[3.0],[2.0],[2.0],[2.0],[3.0],[3.0],[3.0],[3.0],[3.5],[3.5],[3.0],[3.5],[4.0],[4.0],[5.0],[5.0],[5.0],[4.0],[5.0],[4
# ...

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Modify the SOP column to make the bubble size variations more prominent**

# %%
admission_df['SOP'] = admission_df['SOP'] ** 2
chart = px.scatter(admission_df, x = "GRE Score", y = "Chance of Admit", color = "University Rating", size = "SOP")
chart.show()
# Out:
# <div>                            <div id="2096d9c3-8de7-4177-8621-b84ae9229292" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2096d9c3-8de7-4177-8621-b84ae9229292")) {                    Plotly.newPlot(                        "2096d9c3-8de7-4177-8621-b84ae9229292",                        [{"hovertemplate":"GRE Score=%{x}\u003cbr\u003eChance of Admit=%{y}\u003cbr\u003eSOP=%{marker.size}\u003cbr\u003eUniversity Rating=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[4,4,3,3,2,5,3,2,1,3,3,4,4,3,3,3,3,3,3,3,3,4,5,5,5,5,5,2,1,2,2,3,4,5,5,5,2,1,1,2,3,2,2,4,5,5,5,5,3,4,3,2,4,4,3,3,3,2,1,2,2,3,2,2,3,4,3,2,3,4,5,5,5,4,3,2,3,2,2,1,3,4,5,5,5,4,3,2,3,4,2,3,2,2,3,4,2,3,4,3,3,2,2,2,3,3,4,4,5,5,5,4,3,2,3,4,3,4,2,5,5,5,
# ...

# %% [markdown]
# # TASK #3: PLOT INTERACTIVE SINGLE LINEPLOT USING PLOTLY EXPRESS

# %%
# Import the crypto currency dataset
crypto_df = pd.read_csv('/workspaces/Coding/Plotly/crypto_prices.csv')
display(crypto_df)

fig = px.line(crypto_df, x = 'Date', y = 'BTC-USD Price')
fig.update_traces(line_color = 'yellow')
fig.show()
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]
# ...

# %% [markdown]
# # TASK #4: PLOT INTERACTIVE MULTIPLE LINE PLOTS USING PLOTLY EXPRESS

# %%
fig = px.line()

for i in crypto_df.columns[1:]:
    fig.add_scatter(x = crypto_df['Date'], y = crypto_df[i], name = i)
fig.update_layout(hovermode="x")
fig.show()
# Out:
# <div>                            <div id="968251a4-b3b1-4edf-8b5a-3f5163d78530" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("968251a4-b3b1-4edf-8b5a-3f5163d78530")) {                    Plotly.newPlot(                        "968251a4-b3b1-4edf-8b5a-3f5163d78530",                        [{"hovertemplate":"\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"name":"BTC-USD Price","x":["9\u002f17\u002f2014","9\u002f18\u002f2014","9\u002f19\u002f2014","9\u002f20\u002f2014","9\u002f21\u002f2014","9\u002f22\u002f2014","9\u002f23\u002f2014","9\u002f24\u002f2014","9\u002f25
# ...

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Use "compare data on hover" feature to indicate the prices of LTC and ETH when BTC price peaked.**
# - **Use Pandas operations to filter out to filter out the DataFrame and confirm your answers**

# %%
crypto_df[crypto_df['BTC-USD Price'] == crypto_df['BTC-USD Price'].max()]
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 2365  3/13/2021    61243.08594    1924.685425     226.578293

# %% [markdown]
# # TASK #5. PLOT INTERACTIVE PIE CHARTS

# %%
# Define a dictionary with all crypto allocation in a portfolio
# Note that total summation = 100% 
my_dict = {'Allocation(%)':   [20, 25, 10, 30, 15]}
crypto_df = pd.DataFrame(data = my_dict, index = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
display(crypto_df)
fig = px.pie(crypto_df, names = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'], values = 'Allocation(%)', title = 'Crypto Allocation')
fig.show()
# Out:
#      Allocation(%)
# BTC             20
# ETH             25
# LTC             10
# XRP             30
# ADA             15
# ...

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Assume that you became bullish on XRP and decided to allocate 60% of your assets in it. You also decided to equally divide the rest of your assets in other coins (BTC, LTC, ADA, and ETH). Change the allocations and plot the pie chart.**
# - **Use 'hole' attribute and see its impact on the pie chart (External Research is Required)**

# %%
# Define a dictionary with all crypto allocation in a portfolio
# Note that total summation = 100% 
my_dict = {'Allocation(%)':   [10, 10, 10, 60, 10]}
crypto_df = pd.DataFrame(data = my_dict, index = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
display(crypto_df)
fig = px.pie(crypto_df, names = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'], values = 'Allocation(%)', title = 'Crypto Allocation', hole = 0.6)
fig.show()
# Out:
#      Allocation(%)
# BTC             10
# ETH             10
# LTC             10
# XRP             60
# ADA             10
# ...
