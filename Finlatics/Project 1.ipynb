# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/workspaces/Coding/Finlatics/banking_data.csv')
# Out:
# /tmp/ipykernel_1735/1354474528.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
plt.hist(df['age'], color='#4285F4', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequencies')
plt.title('Distribution of Age among Employees')
plt.show()

# %%
job_counts = df['job'].value_counts()
plt.title('Distribution of Job Type among the clients')
pie = plt.pie(job_counts, labels=job_counts.index, autopct='%1.1f%%', shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, radius=1.5)

# %%
marital_counts = df['marital_status'].value_counts()
plt.title('Distribution of Marital Status among the clients')
pie = plt.pie(marital_counts, labels=marital_counts.index, autopct='%1.1f%%', shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, radius=1.5, colors=['maroon', 'blue', 'green'])

# %%
edu_counts = df['education'].value_counts()
plt.title('Distribution of Education among the clients')
pie = plt.pie(edu_counts, labels=edu_counts.index, autopct='%1.1f%%', shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, radius=1.5)

# %%
dafault_counts = df['default'].value_counts()
plt.title('Proportion of clients have credit in default')
pie = plt.pie(default_counts, labels=default_counts.index, autopct='%1.1f%%', shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, radius=1.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 dafault_counts = df['default'].value_counts()
#       2 plt.title('Proportion of clients have credit in default')
# ----> 3 pie = plt.pie(default_counts, labels=default_counts.index, autopct='%1.1f%%', shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, radius=1.5)
#
# NameError: name 'default_counts' is not defined
